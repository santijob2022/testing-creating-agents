# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots(1,2,figsize=(12,5))

n = 30

for i in range(100):    
    A = np.random.randn(n,n) / np.sqrt(n)
    L = np.linalg.eig(A)[0]
    ax[0].plot(np.real(L), np.imag(L),'o')

# Unit circle
theta = np.linspace(0, 2*np.pi, 200)
ax[0].plot(np.cos(theta), np.sin(theta), 'k--')  
    
    
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 30  # Matrix size
num_matrices = 300  # Number of matrices to average over
bins = 10  # Histogram resolution

# Accumulate eigenvalues
all_eigenvalues = []

for _ in range(num_matrices):
    A = np.random.randn(n, n) / np.sqrt(n)
    eigvals = np.linalg.eigvals(A)    
    all_eigenvalues.extend(eigvals)

# Convert to numpy array
all_eigenvalues = np.array(all_eigenvalues)

# Plot histogram as a 2D density (approximation of the spectral distribution)
real_vals = np.real(all_eigenvalues)
imag_vals = np.imag(all_eigenvalues)

# Create 2D histogram
hist, xedges, yedges = np.histogram2d(real_vals, imag_vals, bins=bins, density=True)

# Plotting
fig, ax = plt.subplots(figsize=(8, 8))
X, Y = np.meshgrid((xedges[:-1] + xedges[1:]) / 2,
                   (yedges[:-1] + yedges[1:]) / 2)
pcm = ax.pcolormesh(X, Y, hist.T, shading='auto')
ax.set_xlabel('Real Part')
ax.set_ylabel('Imaginary Part')
ax.set_title('Empirical Spectral Distribution (2D Histogram)')
ax.set_aspect('equal')
fig.colorbar(pcm, ax=ax, label='Density')

## Plotting the eigenvalues
ax.plot(np.real(L), np.imag(L),'o', color='pink')

# Plot unit circle for reference
theta = np.linspace(0, 2 * np.pi, 300)
ax.plot(np.cos(theta), np.sin(theta), 'r--', label='Unit Circle')
ax.legend()

plt.show()
